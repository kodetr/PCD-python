# %%
import cv2 #BGR
import matplotlib.pyplot as plt #RGB

# %%
img = cv2.imread('./images/messi.jpg');

# %%
img.shape
# Out:
# (262, 193, 3)

# %%
img.shape[0] # tinggi -> y
# Out:
# 262

# %%
img.shape[1] # lebar -> x
# Out:
# 193

# %%
262*193
# Out:
# 50566

# %% [markdown]
# # Display

# %%
cv2.imshow('image messi', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# B G R  -> R G B
# 0 1 2     2 1 0
plt.imshow(img[:,:,[2,1,0]])
plt.show()

# %% [markdown]
# # Convert Grayscale

# %%
for y in range(img.shape[0]) : # Y 262
    for x in range(img.shape[1]) : # X 193
        
        blue = img[y,x,0]
        green = img[y,x,1]
        red = img[y,x,2]
        
        grayscale = (0.5 * red) + (0.3 * green) + (0.2 * blue)
        
        img[y,x,0] = grayscale # blue
        img[y,x,1] = grayscale # green
        img[y,x,2] = grayscale # red
        

plt.imshow(img)
plt.show()

# %%
print(img)
# Out:
# [[[119 119 119]
#   [117 117 117]
#   [113 113 113]
#   ...
#   [122 122 122]
#   [119 119 119]
#   [127 127 127]]
#
#  [[119 119 119]
#   [117 117 117]
#   [113 113 113]
#   ...
#   [121 121 121]
#   [118 118 118]
#   [126 126 126]]
#
#  [[117 117 117]
#   [116 116 116]
#   [113 113 113]
#   ...
#   [119 119 119]
#   [117 117 117]
#   [124 124 124]]
#
#  ...
#
#  [[ 64  64  64]
#   [ 63  63  63]
#   [ 61  61  61]
#   ...
#   [ 45  45  45]
#   [ 45  45  45]
#   [ 42  42  42]]
#
#  [[ 68  68  68]
#   [ 67  67  67]
#   [ 65  65  65]
#   ...
#   [ 44  44  44]
#   [ 44  44  44]
#   [ 41  41  41]]
#
#  [[ 72  72  72]
#   [ 70  70  70]
#   [ 68  68  68]
#   ...
#   [ 43  43  43]
#   [ 44  44  44]
#   [ 41  41  41]]]
