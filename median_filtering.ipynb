# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('images/butterflynoise.bmp')

# %%
img
# Out:
# array([[[235, 235, 235],
#         [231, 231, 231],
#         [229, 229, 229],
#         ...,
#         [181, 181, 181],
#         [  0,   0,   0],
#         [181, 181, 181]],
#
#        [[232, 232, 232],
#         [232, 232, 232],
#         [232, 232, 232],
#         ...,
#         [178, 178, 178],
#         [179, 179, 179],
#         [176, 176, 176]],
#
#        [[237, 237, 237],
#         [231, 231, 231],
#         [238, 238, 238],
#         ...,
#         [179, 179, 179],
#         [179, 179, 179],
#         [180, 180, 180]],
#
#        ...,
#
#        [[243, 243, 243],
#         [242, 242, 242],
#         [237, 237, 237],
#         ...,
#         [  0,   0,   0],
#         [ 98,  98,  98],
#         [ 99,  99,  99]],
#
#        [[241, 241, 241],
#         [237, 237, 237],
#         [237, 237, 237],
#         ...,
#         [100, 100, 100],
#         [ 97,  97,  97],
#         [254, 254, 254]],
#
#        [[237, 237, 237],
#         [236, 236, 236],
#         [234, 234, 234],
# ...

# %% [markdown]
# # Display

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# # Median filter

# %%
median_filter = cv2.medianBlur(img, 3)

# %%
plt.imshow(median_filter)
plt.show()
